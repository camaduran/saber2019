# %%
# Cargamos los datasets
import pandas as pd
from pandas import read_csv
# load the dataset
dataset_1 = read_csv('Saber_11__2019-1.csv')
dataset_2 = read_csv('Saber_11__2019-2.csv')


# Concatenamos los datasets
dataset = pd.concat([dataset_1, dataset_2])

#display(dataset.values)

# summarize the dataset
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
print(dataset.describe())

display(dataset.values)
# Out:
# /Users/alpha/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (76,78) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-2-7279402e2571>:18: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#              PERIODO  COLE_CODIGO_ICFES  COLE_COD_DANE_ESTABLECIMIENTO  \
# count  567295.000000  567295.000000      5.672950e+05
# mean   20193.888508   195331.487896      2.088907e+11
# std    0.567492       228307.567910      9.473532e+10
# min    20191.000000   75.000000          1.050010e+11
# 25%    20194.000000   45393.000000       1.190010e+11
# 50%    20194.000000   112128.000000      1.760010e+11
# 75%    20194.000000   193102.000000      3.080011e+11
# ...

# %%
display(dataset.values)
# Out:
# array([['TI', 'COLOMBIA', 'F', ..., 3.0, 'PUBLICAR', 'NO'],
#        ['CC', 'COLOMBIA', 'F', ..., 3.0, 'PUBLICAR', 'NO'],
#        ['TI', 'COLOMBIA', 'M', ..., 3.0, 'PUBLICAR', 'NO'],
#        ...,
#        ['TI', 'COLOMBIA', 'M', ..., 3.0, 'PUBLICAR',
#         'GENERACION E - EXCELENCIA DEPARTAMENTAL'],
#        ['TI', 'COLOMBIA', 'M', ..., 2.0, 'PUBLICAR',
#         'GENERACION E - GRATUIDAD'],
#        ['TI', 'COLOMBIA', 'M', ..., 3.0, 'PUBLICAR',
#         'GENERACION E - EXCELENCIA NACIONAL']], dtype=object)

# %%
print(dataset.head(5))
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 0  TI                 COLOMBIA          F           07/12/2000
# 1  CC                 COLOMBIA          F           23/03/1998
# 2  TI                 COLOMBIA          M           22/03/2001
# 3  CC                 COLOMBIA          M           16/06/1994
# 4  CC                 COLOMBIA          F           21/09/2000
#
#    PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_PAIS_RESIDE ESTU_TIENEETNIA  \
# 0  20191    SB11201910008548  ESTUDIANTE      COLOMBIA         No
# 1  20191    SB11201910004475  ESTUDIANTE      COLOMBIA         No
# 2  20191    SB11201910011427  ESTUDIANTE      COLOMBIA         No
# 3  20191    SB11201910041975  ESTUDIANTE      COLOMBIA         No
# 4  20191    SB11201910014490  ESTUDIANTE      COLOMBIA         No
#
#   ESTU_ETNIA ESTU_DEPTO_RESIDE ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  \
# 0  -          VALLE             76                    CALI
# ...

# %%
num_missing = dataset.isnull().sum()
print(num_missing)
# Out:
# ESTU_TIPODOCUMENTO               0
# ESTU_NACIONALIDAD                0
# ESTU_GENERO                      0
# ESTU_FECHANACIMIENTO             0
# PERIODO                          0
# ESTU_CONSECUTIVO                 0
# ESTU_ESTUDIANTE                  0
# ESTU_PAIS_RESIDE                 0
# ESTU_TIENEETNIA                  0
# ESTU_ETNIA                       0
# ESTU_DEPTO_RESIDE                377
# ESTU_COD_RESIDE_DEPTO            0
# ESTU_MCPIO_RESIDE                377
# ESTU_COD_RESIDE_MCPIO            0
# FAMI_ESTRATOVIVIENDA             26
# FAMI_PERSONASHOGAR               8463
# FAMI_CUARTOSHOGAR                6418
# FAMI_EDUCACIONPADRE              8292
# FAMI_EDUCACIONMADRE              20959
# FAMI_TRABAJOLABORPADRE           8131
# FAMI_TRABAJOLABORMADRE           7469
# FAMI_TIENEINTERNET               8337
# FAMI_TIENESERVICIOTV             22280
# FAMI_TIENECOMPUTADOR             8185
# FAMI_TIENELAVADORA               7643
# ...

# %%
pd.value_counts(dataset['FAMI_TRABAJOLABORMADRE'])
# Out:
# Trabaja en el hogar, no trabaja o estudia                                                               218923
# Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc    49919
# Trabaja como personal de limpieza, mantenimiento, seguridad o construcción                              47817
# Trabaja como profesional (por ejemplo médico, abogado, ingeniero)                                       46793
# Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)                  46305
# Es vendedor o trabaja en atención al público                                                            41680
# No aplica                                                                                               28252
# Es agricultor, pesquero o jornalero                                                                     17274
# ...

# %%
pd.value_counts(dataset['FAMI_TIENEINTERNET'])
# Out:
# Si    331284
# No    203665
# -     24009
# Name: FAMI_TIENEINTERNET, dtype: int64

# %%
pd.value_counts(dataset['FAMI_NUMLIBROS'])
# Out:
# 0 A 10 LIBROS        212037
# 11 A 25 LIBROS       158610
# 26 A 100 LIBROS      111570
# MÁS DE 100 LIBROS    38664
# -                    37760
# Name: FAMI_NUMLIBROS, dtype: int64

# %%
pd.value_counts(dataset['FAMI_SITUACIONECONOMICA'])
# Out:
# Igual    334714
# Mejor    139318
# Peor     74505
# -        10499
# Name: FAMI_SITUACIONECONOMICA, dtype: int64

# %%
pd.value_counts(dataset['ESTU_DEDICACIONLECTURADIARIA'])
# Out:
# 30 minutos o menos            205979
# Entre 30 y 60 minutos         149862
# No leo por entretenimiento    99863
# Entre 1 y 2 horas             57681
# -                             32496
# Más de 2 horas                20787
# Name: ESTU_DEDICACIONLECTURADIARIA, dtype: int64

# %%
pd.value_counts(dataset['COLE_BILINGUE'])
# Out:
# N    466630
# -    91546
# S    9119
# Name: COLE_BILINGUE, dtype: int64

# %%
pd.value_counts(dataset['COLE_JORNADA'])
# Out:
# MAÑANA      263298
# COMPLETA    98154
# UNICA       67479
# TARDE       59667
# SABATINA    42322
# NOCHE       36375
# Name: COLE_JORNADA, dtype: int64

# %%
pd.value_counts(dataset['PUNT_INGLES'])
# Out:
# 45.0     16601
# 54.0     16493
# 40.0     16472
# 46.0     16459
# 53.0     16387
# 41.0     16333
# 39.0     16273
# 44.0     16162
# 47.0     16109
# 43.0     16086
# 42.0     16075
# 55.0     16039
# 52.0     15975
# 48.0     15867
# 50.0     15835
# 51.0     15767
# 49.0     15708
# 38.0     15574
# 56.0     14975
# 37.0     14800
# 57.0     13733
# 36.0     13727
# 58.0     12658
# 35.0     12384
# 34.0     11277
# 59.0     11228
# 60.0     10321
# 33.0     10272
# 61.0     9112
# 32.0     9046
# 31.0     8308
# 62.0     8242
# 63.0     7499
# 30.0     7413
# 64.0     6761
# 29.0     6455
# 65.0     5989
# 28.0     5653
# 66.0     5616
# 67.0     5013
# 27.0     4896
# 68.0     4583
# 69.0     4385
# 70.0     4326
# 71.0     4271
# 72.0     3671
# 75.0     3572
# 26.0     3409
# 74.0     3331
# 73.0     3232
# 76.0     2674
# 25.0     2657
# 77.0     2413
# 78.0     2356
# 24.0     2196
# 79.0     2079
# 81.0     1843
# 80.0     1751
# 23.0     1657
# 100.0    1438
# ...
